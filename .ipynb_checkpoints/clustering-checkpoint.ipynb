# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans

from kneed import KneeLocator

# %%
data = pd.read_csv("data/ExportBales_1.csv", sep=";")
data
# Out:
#                    _time  bale_info_bale_length  bale_info_bale_weight  \
# 0   2021-07-31T08:09:17Z                   3200                 211000
# 1   2021-07-31T08:10:13Z                   1960                 361000
# 2   2021-07-31T08:11:02Z                   2440                 445000
# 3   2021-07-31T08:12:04Z                   2410                 430000
# 4   2021-07-31T08:12:50Z                   2430                 454000
# 5   2021-07-31T08:23:23Z                   2460                 402000
# 6   2021-07-31T08:24:14Z                   2420                 434000
# 7   2021-07-31T08:25:32Z                   2440                 431000
# 8   2021-07-31T09:38:19Z                   2430                 421000
# 9   2021-07-31T09:41:43Z                   2420                 450000
# 10  2021-07-31T09:42:53Z                    470                 456000
# 11  2021-07-31T09:44:28Z                   2460                 450000
# ...

# %%
data["Colonne1"].unique()
# Out:
# array([1])

# %%
data.drop(inplace=True, columns=data.columns[-5:])
data
# Out:
#                    _time  bale_info_bale_length  bale_info_bale_weight  \
# 0   2021-07-31T08:09:17Z                   3200                 211000
# 1   2021-07-31T08:10:13Z                   1960                 361000
# 2   2021-07-31T08:11:02Z                   2440                 445000
# 3   2021-07-31T08:12:04Z                   2410                 430000
# 4   2021-07-31T08:12:50Z                   2430                 454000
# 5   2021-07-31T08:23:23Z                   2460                 402000
# 6   2021-07-31T08:24:14Z                   2420                 434000
# 7   2021-07-31T08:25:32Z                   2440                 431000
# 8   2021-07-31T09:38:19Z                   2430                 421000
# 9   2021-07-31T09:41:43Z                   2420                 450000
# 10  2021-07-31T09:42:53Z                    470                 456000
# 11  2021-07-31T09:44:28Z                   2460                 450000
# ...

# %%
# Calcul le nombre de cluster

# %%
X = data.loc[:,["latitude", "longitude"]]
X
# Out:
#      latitude  longitude
# 0   52.115374  11.078973
# 1   52.115187  11.082384
# 2   52.115149  11.080707
# 3   52.115188  11.079040
# 4   52.115411  11.079829
# 5   52.115257  11.079463
# 6   52.115479  11.079626
# 7   52.115429  11.081506
# 8   52.115068  11.080748
# 9   52.115085  11.079170
# 10  52.115843  11.081508
# 11  52.115897  11.079028
# 12  52.115908  11.081440
# 13  52.115734  11.084846
# 14  52.115858  11.085725
# 15  52.115896  11.084514
# 16  52.115945  11.082991
# 17  52.115967  11.084042

# %%
# Elbow method
max_clust = 15

sse = []
for k in range(1, max_clust):
    kmeans = KMeans(n_clusters=k, n_init=10, max_iter=300, tol=0.0001, random_state=42)
    kmeans.fit(X)
    sse.append(kmeans.inertia_)
    print(k, kmeans.inertia_, flush=True)
    
plt.plot(range(1,max_clust), sse, marker="o")
plt.title("Sum of the squared error depending on the number of cluster")

kl = KneeLocator(range(1,max_clust), sse, curve="convex", direction="decreasing")
elbow = kl.elbow
print("Elbow :", elbow)

plt.plot([elbow, elbow], [np.min(sse), np.max(sse)])
plt.tight_layout()
plt.show()
# Out:
# 1 8.504449382276284e-05
# 2 2.0673697553332797e-05
# 3 7.64430395179505e-06
# 4 4.3960349503653514e-06
# 5 3.2093807995323907e-06
# 6 2.0624204778575726e-06
# 7 1.4725294391667635e-06
# 8 1.0011594291645124e-06
# 9 6.525070116667093e-07
# 10 3.6554503000054947e-07
# 11 2.3228748166712142e-07
# 12 1.6225333999984283e-07
# 13 9.418781500000925e-08
# 14 4.5036219999818786e-08
# Elbow : 3

# %%
# relancer kmeans avec le meilleur nombre de clusters 
kmeans = KMeans(n_clusters=elbow, n_init=10, max_iter=300, tol=0.0001, random_state=42)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=3, random_state=42)

# %%
# Final locations of the centroid
centers = pd.DataFrame(data=kmeans.cluster_centers_, columns=X.columns)
centers
# Out:
#     latitude  longitude
# 0  52.115384  11.079304
# 1  52.115864  11.084782
# 2  52.115504  11.081612

# %%
kmeans.labels_
# Out:
# array([0, 2, 2, 0, 0, 0, 0, 2, 2, 0, 2, 0, 2, 1, 1, 1, 2, 1], dtype=int32)

# %%
# Plot des données et des centres 
colors = ["indianred", "sandybrown", "gold", "darkseagreen", "paleturquoise", "lightskyblue", "plum", "pink"] 

plt.figure(figsize=(19,10))
plt.scatter(X["latitude"], X["longitude"], c=kmeans.labels_, cmap=colors[:elbow])
plt.plot(centers["latitude"], centers["longitude"], "*", ms=10, c=colors[c])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-95118635e9d2> in <module>
#       3
#       4 plt.figure(figsize=(19,10))
# ----> 5 plt.scatter(X["latitude"], X["longitude"], c=kmeans.labels_, cmap=colors[:elbow])
#       6 plt.plot(centers["latitude"], centers["longitude"], "*", ms=10)
#       7 plt.show()
#
# ~/.local/lib/python3.8/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    3066         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    3067         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 3068     __ret = gca().scatter(
#    3069         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    3070         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# ...

# %%
def plot_centers(X, centers):
    """
    Plot each datetime projected on each component. These points are colored according to their cluster. Cluster centers are stars with the same color for time component and 
    lines for other components. 
    """
    fig, axs = plt.subplots(figsize=(19,15), nrows=4, ncols=3, tight_layout=True)
    axs[0,0].set_axis_off()
    axs[0,2].set_axis_off()
#     axs[0,1].pie(proportion, labels=lab_types, counterclock=False, startangle=90, autopct="%1.0f%%", pctdistance=0.7, colors = colors)
#     axs[0,1].set_title("Proportion of each cluster")
    
    for i in range (nb_comp): # i = idx of component : 0-5 => cos+sin of columns 0-11 | 6 => year | or occ
        print((i//3)+1, i%3)
        ax = axs[(i//3)+1, i%3]
        if i < nb_cos: #sin/cos columns next to each other
            # Plot of circles representing our data 
            sin = X.columns[i*2]
            cos = X.columns[i*2+1]
            X.plot.scatter(sin, cos, s=5, c=colors_pt, ax=ax).set_aspect('equal')

            # Plot of cluster centers 
            col_centers_coord = centers.iloc[:, i*2:i*2+2] # sin and cos of this component for each cluster 

            for c in range (len(col_centers_coord.index)):
                center = col_centers_coord.iloc[c,:]
                ax.plot(center[0], center[1], '*', c=colors[c], ms=13) # x=sin, y=cos

            ax.set_xlim(-1.1,1.1)
            ax.set_ylim(-1.1,1.1)
            ax.set_title(X.columns[i*2][:-4])

        else : 
            ax.set_title(X.columns[i+nb_cos])
            # Plot by cluster to have the right colors 
            for clust in range(centers.shape[0]):
                x = [i for i in range(labels.shape[0]) if labels[i]==clust]
                ax.plot(X.loc[x, X.columns[i+nb_cos]], marker='o', c=colors[clust], linestyle='')

            # Plot of cluster centers 
            occ_centers = centers.iloc[:,i+nb_cos]
            for c in range(len(occ_centers)): # loop on year component of centers 
                o_center = occ_centers[c] # value of the year for this center 
                ax.plot([0,X.shape[0]], [o_center, o_center], color=colors[c]) # a horizontal line with this value
    axs[3,2].set_axis_off()
    fig.tight_layout()
    plt.show()
    
plot_centers(X, centers)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-c38830220b4d> in <module>
#      46     plt.show()
#      47
# ---> 48 plot_centers(X, centers)
#
# <ipython-input-11-c38830220b4d> in plot_centers(X, centers)
#      10 #     axs[0,1].set_title("Proportion of each cluster")
#      11
# ---> 12     for i in range (nb_comp): # i = idx of component : 0-5 => cos+sin of columns 0-11 | 6 => year | or occ
#      13         print((i//3)+1, i%3)
#      14         ax = axs[(i//3)+1, i%3]
#
# NameError: name 'nb_comp' is not defined
